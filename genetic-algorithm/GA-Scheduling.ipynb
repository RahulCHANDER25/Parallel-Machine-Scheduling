# %% [markdown]
# # Genetic Algorithm - Real-World Semiconductor Workshop Scheduling
#
# In this notebook we will solve a real world scheduling problem using population based **Genetic Algorithm**.

# %% [markdown]
# ## Data Structure
#
# Our data strucure is organised like this: ...

# %% [markdown]
# ## Algorithm
#
# We have our main Genetic Algorithm there.
# Our main component:
# * ...
# * ...
